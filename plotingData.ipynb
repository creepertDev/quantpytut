# %%
import datetime as dt
import pandas as pd
import yfinance as yf
import plotly.offline as pyo
import plotly.graph_objects as go
from plotly.subplots import make_subplots

pyo.init_notebook_mode(connected = True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>

# %%
end = dt.datetime.now()
start = dt.datetime(2025,1,1)

df = yf.download("QQQ", start, end)

print(df.head())
df.columns = df.columns.droplevel(1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             QQQ         QQQ         QQQ         QQQ       QQQ
# Date
# 2025-01-02  507.016083  513.385710  502.524535  511.060423  36389800
# 2025-01-03  515.313538  516.376805  509.301658  510.116440  29059500
# 2025-01-06  521.235962  524.594677  518.741823  520.719279  36109700
# 2025-01-07  511.934875  522.676781  510.046880  522.279337  36690300
# 2025-01-08  512.024292  513.663862  507.353886  511.835486  30777800

# %%
df['MA50'] = df['Close'].rolling(window = 50, min_periods = 0).mean()
df['MA200'] = df['Close'].rolling(window = 200, min_periods = 0).mean()

df['MA50'].head(20)
# Out:
# Date
# 2025-01-02    507.016083
# 2025-01-03    511.164810
# 2025-01-06    514.521861
# 2025-01-07    513.875114
# 2025-01-08    513.504950
# 2025-01-10    511.919993
# 2025-01-13    510.556492
# 2025-01-14    509.474247
# 2025-01-15    509.915470
# 2025-01-16    509.908734
# 2025-01-17    510.685541
# 2025-01-21    511.586273
# 2025-01-22    512.861328
# 2025-01-23    514.034446
# 2025-01-24    514.851742
# 2025-01-27    514.609198
# 2025-01-28    514.839425
# 2025-01-29    514.989975
# 2025-01-30    515.240782
# 2025-01-31    515.428746
# Name: MA50, dtype: float64

# %%
df['MA50'] = df['Close'].rolling(window=10, min_periods=0).mean()
print(df['MA50'].head(20))
# Out:
# Date
# 2025-01-02    507.016083
# 2025-01-03    511.164810
# 2025-01-06    514.521861
# 2025-01-07    513.875114
# 2025-01-08    513.504950
# 2025-01-10    511.919993
# 2025-01-13    510.556492
# 2025-01-14    509.474247
# 2025-01-15    509.915470
# 2025-01-16    509.908734
# 2025-01-17    511.052487
# 2025-01-21    511.670566
# 2025-01-22    512.363168
# 2025-01-23    514.098178
# 2025-01-24    515.525137
# 2025-01-27    516.222720
# 2025-01-28    517.837479
# 2025-01-29    519.402557
# 2025-01-30    520.033563
# 2025-01-31    520.948758
# Name: MA50, dtype: float64

# %%
fig = make_subplots(rows = 2, cols = 1, shared_xaxes = True, vertical_spacing = 0.1, subplot_titles = ('QQQ', 'Volume'), row_width = [0.2,0.7])

# %%
fig.add_trace(go.Candlestick(x =df.index, open = df['Open'], high = df['High'], low = df['Low'], close = df['Close'], name = 'OHLC'), row = 1, col = 1)
# fig.add_trace(
#     go.Bar(x=df.index, y=df['Volume'], name='Volume'),
#     row=2, col=1
# )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.add_trace(go.Scatter(x = df.index, y = df['MA50'], marker_color = 'hotpink', name = 'MA50'), row = 1, col = 1)
fig.add_trace(go.Scatter(x = df.index, y = df['MA200'], marker_color = 'blue', name = 'MA200'), row = 1, col = 1)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.add_trace(go.Bar(x = df.index, y = df['Volume'], marker_color = 'red', showlegend = False), row = 2, col = 1)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.update_layout(
    title='QQQ Historical Price Chart',
    xaxis=dict(tickfont=dict(size=12)),
    yaxis=dict(
        title=dict(text='Price ($/Share)', font=dict(size=14)),
        tickfont=dict(size=12)
    ),
    autosize=False,
    width=800,
    height=500,
    margin=dict(l=50, r=50, b=100, t=100, pad=5),
    paper_bgcolor='LightSteelBlue'
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.update(layout_xaxis_rangeslider_visible = False)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
